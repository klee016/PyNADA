# %%
#from commons import *
from datasets import *

# %%
set_api_key('cf16a23a3cfc6a928f63dd3c8daf8796')

# %%
set_api_url('http://training.ihsn.org/index.php/api/')

# %%
get_api_key()
# Out:
# 'cf16a23a3cfc6a928f63dd3c8daf8796'

# %%
get_api_url()
# Out:
# 'http://training.ihsn.org/index.php/api/'

# %%
list_datasets()
# Out:
#         type repositoryid                         idno  \
# id
# 1   document      central                   WB_WPS9412
# 2   document      central                   WB_WPS9411
# 3      image      central                       WBG-HQ
# 4     script      central          RR_WLD_2020_PFC_v01
# 6      table      central  BGD_RRRC-UNHCR-IOM_20190108
# 7     survey      central         this-is-a-test-study
# 8     survey      central          CIV_1985_EPAM_v01_M
# 9     survey      central           ERI_1995_DHS_v01_M
# 10    survey      central           ALB_1996_EWS_v01_M
# 11    survey      central          ALB_2000_MICS_v01_M
# 12    survey      central         ALB_2002_ES_v01_M_WB
# 13    survey      central          ALB_2002_LSMS_v01_M
# 14    survey      central          ALB_2003_LSMS_v01_M
# 15    survey      central          ALB_2004_LSMS_v01_M
# 16    survey      central         ALB_2005_ES_v01_M_WB
# 17    survey      central          ALB_2005_LSMS_v01_M
#
# ...

# %%
get_api_key()
# Out:
# 'cf16a23a3cfc6a928f63dd3c8daf8796'

# %%
print(api_key)

# %%
import requests

# %%
headers = {
    'X-API-KEY': 'cf16a23a3cfc6a928f63dd3c8daf8796'
}

# %%
collections = requests.get('http://training.ihsn.org/index.php/api/datasets', headers=headers)

# %%
for item in collections.json():
    print(item)
# Out:
# status
# found
# datasets

# %%
collections.json()['datasets']
# Out:
# [{'id': '1',
#   'type': 'document',
#   'repositoryid': 'central',
#   'idno': 'WB_WPS9412',
#   'title': 'Predicting Food Crises',
#   'abbreviation': '0',
#   'authoring_entity': 'Bo P. J. Andree, Andres Chamorro, Aart Kraay, Phoebe Spencer, Dieter Wang',
#   'nation': 'Afghanistan, Burkina Faso, Chad, Congo, Dem. Rep., Ethiopia, Guatemala, Haiti, Kenya, Malawi, Mali, Mauritania, Mozambique, Niger, Nigeria, Somal...',
#   'year_start': '2020',
#   'year_end': '2020',
#   'link_da': None,
#   'published': '1',
#   'created': '2020-10-22T12:22:15+00:00',
#   'changed': '2020-10-22T12:22:15+00:00',
#   'varcount': None,
#   'total_views': '9',
#   'total_downloads': '0',
#   'created_by': '4',
#   'changed_by': '4',
#   'formid': None},
#  {'id': '2',
#   'type': 'document',
#   'repositoryid': 'central',
#   'idno': 'WB_WPS9411',
#   'title': 'Predicting Food Crises',
#   'abbreviation': '0',
# ...

# %%
collections = requests.get('http://training.ihsn.org/index.php/api/datasets')

# %%
collections
# Out:
# <Response [400]>

# %%
from datasets import list_all_datasets

# %%
list_all_datasets()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-49afac2af074> in <module>
# ----> 1 list_all_datasets()
#
# ~\Documents\WB work\202012_FCV Data Platform Development\Github\PyNADA\pynada\datasets.py in list_all_datasets()
#      10     if collections.status_code != 200:
#      11         # This means something went wrong.
# ---> 12         raise Exception('GET /tasks/ {}'.format(collections.json()))
#      13
#      14     for item in collections.json():
#
# Exception: GET /tasks/ {'status': 'ACCESS-DENIED', 'message': 'Access denied'}
